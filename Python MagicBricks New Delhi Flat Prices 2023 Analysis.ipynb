# %% [markdown]
# Data Cleaning And Data Preparation of MagicBricks New Delhi Flat Prices 2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Flat_prices = pd.read_csv(r"C:\Users\vishw\OneDrive\Desktop\Python Data Analyst Project\MagicBricks New Delhi Flat Prices 2023\top_all.csv")

# %%
Flat_prices.head()
# Out:
#        Price BHK   beds   baths     balcony    covered-parking Carpet Area  \
# 0    ₹6.0 Cr   3  3Beds  3Baths         NaN  1 Covered Parking        2300
# 1   ₹4.75 Cr   3  3Beds  5Baths         NaN  2 Covered Parking        2250
# 2   ₹4.50 Cr   3  3Beds  4Baths         NaN  1 Covered Parking        1872
# 3   ₹1.70 Cr   3  3Beds  2Baths  4Balconies  1 Covered Parking        1450
# 4  ₹75.0 Lac   3  3Beds  3Baths    1Balcony  1 Covered Parking        1350
#
#                            Developer                      Project  \
# 0                           DLF Ltd.              DLF One Midtown
# 1                         Indus Home         Luxury Builder Floor
# 2                    Metro Buildtech        Premium Builder Floor
# 3  Cooperative Group Housing Society             Nishat Apartment
# 4    Delhi Development Authority DDA  DDA Freedom Fighter Enclave
#
#                   Floor Transaction type              Status  Lifts  \
# ...

# %%
Flat_prices.tail()
# Out:
#          Price              BHK   beds   baths     balcony    covered-parking  \
# 981  ₹85.0 Lac    725 Sq-ft  2   2Beds  2Baths         NaN                NaN
# 982  ₹32.0 Lac               2   2Beds     NaN    1Balcony  1 Covered Parking
# 983   ₹2.50 Cr   1850 Sq-ft  3   3Beds  3Baths    1Balcony                NaN
# 984  ₹50.0 Lac    150 Sq-ft  2   2Beds  2Baths    1Balcony                NaN
# 985   ₹2.25 Cr               2   2Beds  2Baths  2Balconies                NaN
#
#     Carpet Area                        Developer        Project  \
# 981         635                              NaN            NaN
# 982         350  Delhi Development Authority DDA  DDA LIG Flats
# 983        1850                              NaN            NaN
# 984         150                              NaN            NaN
# 985        1250                              NaN            NaN
#
#                         Floor Transaction type         Status  Lifts  \
# ...

# %%
Flat_prices.shape
# Out:
# (986, 18)

# %%
Flat_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Price                  986 non-null    object
#  1   BHK                    986 non-null    object
#  2   beds                   986 non-null    object
#  3   baths                  921 non-null    object
#  4   balcony                715 non-null    object
#  5   covered-parking        341 non-null    object
#  6   Carpet Area            986 non-null    object
#  7   Developer              307 non-null    object
#  8   Project                357 non-null    object
#  9   Floor                  972 non-null    object
#  10  Transaction type       986 non-null    object
#  11  Status                 927 non-null    object
#  12  Lifts                  112 non-null    float64
#  13  Address                986 non-null    object
# ...

# %%
Flat_prices.isna().sum()
# Out:
# Price                      0
# BHK                        0
# beds                       0
# baths                     65
# balcony                  271
# covered-parking          645
# Carpet Area                0
# Developer                679
# Project                  629
# Floor                     14
# Transaction type           0
# Status                    59
# Lifts                    874
# Address                    0
# Furnishing                 2
# Flooring                 262
# Water Availability       407
# Status of Electricity    403
# dtype: int64

# %%
Flat_prices.drop(["Water Availability","Status of Electricity","Lifts","Project","Developer","covered-parking"],axis=1,inplace=True)

# %%
Flat_prices.head()
# Out:
#        Price BHK   beds   baths     balcony Carpet Area                 Floor  \
# 0    ₹6.0 Cr   3  3Beds  3Baths         NaN        2300                   NaN
# 1   ₹4.75 Cr   3  3Beds  5Baths         NaN        2250                   NaN
# 2   ₹4.50 Cr   3  3Beds  4Baths         NaN        1872                   NaN
# 3   ₹1.70 Cr   3  3Beds  2Baths  4Balconies        1450  3 (Out of 10 Floors)
# 4  ₹75.0 Lac   3  3Beds  3Baths    1Balcony        1350   3 (Out of 5 Floors)
#
#   Transaction type              Status  \
# 0     New Property  Under Construction
# 1     New Property       Ready to Move
# 2     New Property       Ready to Move
# 3           Resale       Ready to Move
# 4     New Property       Ready to Move
#
#                                              Address      Furnishing  \
# 0            Moti Nagar, New Delhi - West, Delhi NCR  Semi-Furnished
# 1                GK II, New Delhi - South, Delhi NCR  Semi-Furnished
# ...

# %%
Flat_prices.isna().sum()
# Out:
# Price                 0
# BHK                   0
# beds                  0
# baths                65
# balcony             271
# Carpet Area           0
# Floor                14
# Transaction type      0
# Status               59
# Address               0
# Furnishing            2
# Flooring            262
# dtype: int64

# %%
Flat_prices.baths.unique()
# Out:
# array(['3Baths', '5Baths', '4Baths', '2Baths', nan], dtype=object)

# %%
Flat_prices["baths"] = Flat_prices["baths"].str.replace('Baths','')

# %%
Flat_prices.baths.unique()
# Out:
# array(['3', '5', '4', '2', nan], dtype=object)

# %%
Flat_prices["baths"] = Flat_prices.baths.fillna("1")

# %%
Flat_prices.baths.unique()
# Out:
# array(['3', '5', '4', '2', '1'], dtype=object)

# %%
Flat_prices.baths.astype(int)
# Out:
# 0      3
# 1      5
# 2      4
# 3      2
# 4      3
#       ..
# 981    2
# 982    1
# 983    3
# 984    2
# 985    2
# Name: baths, Length: 986, dtype: int32

# %%
Flat_prices.head()
# Out:
#        Price BHK   beds baths     balcony Carpet Area                 Floor  \
# 0    ₹6.0 Cr   3  3Beds     3         NaN        2300                   NaN
# 1   ₹4.75 Cr   3  3Beds     5         NaN        2250                   NaN
# 2   ₹4.50 Cr   3  3Beds     4         NaN        1872                   NaN
# 3   ₹1.70 Cr   3  3Beds     2  4Balconies        1450  3 (Out of 10 Floors)
# 4  ₹75.0 Lac   3  3Beds     3    1Balcony        1350   3 (Out of 5 Floors)
#
#   Transaction type              Status  \
# 0     New Property  Under Construction
# 1     New Property       Ready to Move
# 2     New Property       Ready to Move
# 3           Resale       Ready to Move
# 4     New Property       Ready to Move
#
#                                              Address      Furnishing  \
# 0            Moti Nagar, New Delhi - West, Delhi NCR  Semi-Furnished
# 1                GK II, New Delhi - South, Delhi NCR  Semi-Furnished
# ...

# %%
Flat_prices.beds.unique()
# Out:
# array(['3Beds', '2Beds'], dtype=object)

# %%
Flat_prices["beds"] = Flat_prices["beds"].str.replace('Beds','')

# %%
Flat_prices.beds.astype(int)
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 981    2
# 982    2
# 983    3
# 984    2
# 985    2
# Name: beds, Length: 986, dtype: int32

# %%
Flat_prices.balcony.unique()
# Out:
# array([nan, '4Balconies', '1Balcony', '3Balconies', '2Balconies',
#        '5Balconies'], dtype=object)

# %%
Flat_prices["balcony"] = Flat_prices["balcony"].str.replace('Balconies','')

# %%
Flat_prices["balcony"] = Flat_prices["balcony"].str.replace('Balcony','')

# %%
Flat_prices["balcony"]=Flat_prices.balcony.fillna("1")

# %%
Flat_prices.balcony.astype(int)
# Out:
# 0      1
# 1      1
# 2      1
# 3      4
# 4      1
#       ..
# 981    1
# 982    1
# 983    1
# 984    1
# 985    2
# Name: balcony, Length: 986, dtype: int32

# %%
Flat_prices.head()
# Out:
#        Price BHK beds baths balcony Carpet Area                 Floor  \
# 0    ₹6.0 Cr   3    3     3       1        2300                   NaN
# 1   ₹4.75 Cr   3    3     5       1        2250                   NaN
# 2   ₹4.50 Cr   3    3     4       1        1872                   NaN
# 3   ₹1.70 Cr   3    3     2       4        1450  3 (Out of 10 Floors)
# 4  ₹75.0 Lac   3    3     3       1        1350   3 (Out of 5 Floors)
#
#   Transaction type              Status  \
# 0     New Property  Under Construction
# 1     New Property       Ready to Move
# 2     New Property       Ready to Move
# 3           Resale       Ready to Move
# 4     New Property       Ready to Move
#
#                                              Address      Furnishing  \
# 0            Moti Nagar, New Delhi - West, Delhi NCR  Semi-Furnished
# 1                GK II, New Delhi - South, Delhi NCR  Semi-Furnished
# 2                 GK I, New Delhi - South, Delhi NCR  Semi-Furnished
# ...

# %%
Flat_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             986 non-null    object
#  1   BHK               986 non-null    object
#  2   beds              986 non-null    object
#  3   baths             986 non-null    object
#  4   balcony           986 non-null    object
#  5   Carpet Area       986 non-null    object
#  6   Floor             972 non-null    object
#  7   Transaction type  986 non-null    object
#  8   Status            927 non-null    object
#  9   Address           986 non-null    object
#  10  Furnishing        984 non-null    object
#  11  Flooring          724 non-null    object
# dtypes: object(12)
# memory usage: 92.6+ KB

# %%
Flat_prices.isna().sum()
# Out:
# Price                 0
# BHK                   0
# beds                  0
# baths                 0
# balcony               0
# Carpet Area           0
# Floor                14
# Transaction type      0
# Status               59
# Address               0
# Furnishing            2
# Flooring            262
# dtype: int64

# %%
Flat_prices.dropna(inplace=True)

# %%
Flat_prices.drop(["Flooring"],axis=1,inplace=True)

# %%
Flat_prices.head()
# Out:
#        Price BHK beds baths balcony Carpet Area                 Floor  \
# 3   ₹1.70 Cr   3    3     2       4        1450  3 (Out of 10 Floors)
# 4  ₹75.0 Lac   3    3     3       1        1350   3 (Out of 5 Floors)
# 5   ₹1.95 Cr   3    3     3       4        1500  7 (Out of 10 Floors)
# 6   ₹1.85 Cr   3    3     3       3        1350   6 (Out of 8 Floors)
# 8   ₹1.89 Cr   3    3     3       2        1600  4 (Out of 10 Floors)
#
#   Transaction type         Status  \
# 3           Resale  Ready to Move
# 4     New Property  Ready to Move
# 5           Resale  Ready to Move
# 6           Resale  Ready to Move
# 8           Resale  Ready to Move
#
#                                              Address      Furnishing
# 3  Dwarka Sector 19, New Delhi, Sector 19 Dwarka,...       Furnished
# 4  Freedom Fighter Enclave Saket New Delhi, Saket...  Semi-Furnished
# 5  Dwarka Sector 4, New Delhi, Sector 4 Dwarka, N...  Semi-Furnished
# ...

# %%
Flat_prices.isna().sum()
# Out:
# Price               0
# BHK                 0
# beds                0
# baths               0
# balcony             0
# Carpet Area         0
# Floor               0
# Transaction type    0
# Status              0
# Address             0
# Furnishing          0
# dtype: int64

# %%
Flat_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913 entries, 3 to 985
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             913 non-null    object
#  1   BHK               913 non-null    object
#  2   beds              913 non-null    object
#  3   baths             913 non-null    object
#  4   balcony           913 non-null    object
#  5   Carpet Area       913 non-null    object
#  6   Floor             913 non-null    object
#  7   Transaction type  913 non-null    object
#  8   Status            913 non-null    object
#  9   Address           913 non-null    object
#  10  Furnishing        913 non-null    object
# dtypes: object(11)
# memory usage: 85.6+ KB

# %%
Flat_prices.Price.unique()
# Out:
# array(['₹1.70 Cr', '₹75.0 Lac', '₹1.95 Cr', '₹1.85 Cr', '₹1.89 Cr',
#        '₹37.0 Lac', '₹4.05 Cr', '₹2.40 Cr', '₹2.45 Cr', '₹2.10 Cr',
#        '₹27.5 Lac', '₹61.5 Lac', '₹1.83 Cr', '₹1.15 Cr', '₹2.20 Cr',
#        '₹1.62 Cr', '₹3.0 Cr', '₹1.20 Cr', '₹44.5 Lac', '₹2.47 Cr',
#        '₹40.0 Lac', '₹30.0 Lac', '₹1.39 Cr', '₹93.0 Lac', '₹1.28 Cr',
#        '₹3.15 Cr', '₹1.74 Cr', '₹4.85 Cr', '₹1.87 Cr', '₹24.5 Lac',
#        '₹1.73 Cr', '₹1.92 Cr', '₹1.59 Cr', '₹22.5 Lac', '₹1.11 Cr',
#        '₹1.75 Cr', '₹2.0 Cr', '₹1.90 Cr', '₹2.30 Cr', '₹21.0 Lac',
#        '₹4.50 Cr', '₹2.25 Cr', '₹1.32 Cr', '₹2.05 Cr', '₹55.0 Lac',
#        '₹4.25 Cr', '₹1.17 Cr', '₹1.40 Cr', '₹1.60 Cr', '₹2.35 Cr',
#        '₹25.0 Lac', '₹1.64 Cr', '₹1.10 Cr', '₹4.10 Cr', '₹33.0 Lac',
#        '₹2.70 Cr', '₹24.0 Lac', '₹1.30 Cr', '₹7.50 Cr', '₹5.0 Cr',
#        '₹5.50 Cr', '₹59.0 Lac', '₹21.50 Cr', '₹3.25 Cr', '₹50.0 Lac',
#        '₹65.0 Lac', '₹2.41 Cr', '₹4.60 Cr', '₹2.50 Cr', '₹5.99 Cr',
# ...

# %%
Flat_prices["Price"] = Flat_prices["Price"].str.replace('₹','')

# %%
Flat_prices.Price.unique()
# Out:
# array(['1.70 ', '75.0 Lac', '1.95 ', '1.85 ', '1.89 ', '37.0 Lac',
#        '4.05 ', '2.40 ', '2.45 ', '2.10 ', '27.5 Lac', '61.5 Lac',
#        '1.83 ', '1.15 ', '2.20 ', '1.62 ', '3.0 ', '1.20 ', '44.5 Lac',
#        '2.47 ', '40.0 Lac', '30.0 Lac', '1.39 ', '93.0 Lac', '1.28 ',
#        '3.15 ', '1.74 ', '4.85 ', '1.87 ', '24.5 Lac', '1.73 ', '1.92 ',
#        '1.59 ', '22.5 Lac', '1.11 ', '1.75 ', '2.0 ', '1.90 ', '2.30 ',
#        '21.0 Lac', '4.50 ', '2.25 ', '1.32 ', '2.05 ', '55.0 Lac',
#        '4.25 ', '1.17 ', '1.40 ', '1.60 ', '2.35 ', '25.0 Lac', '1.64 ',
#        '1.10 ', '4.10 ', '33.0 Lac', '2.70 ', '24.0 Lac', '1.30 ',
#        '7.50 ', '5.0 ', '5.50 ', '59.0 Lac', '21.50 ', '3.25 ',
#        '50.0 Lac', '65.0 Lac', '2.41 ', '4.60 ', '2.50 ', '5.99 ',
#        '95.0 Lac', '1.26 ', '1.67 ', '1.97 ', '3.30 ', '4.15 ', '3.80 ',
#        '42.5 Lac', '1.80 ', '1.05 ', '1.55 ', '6.50 ', '85.0 Lac',
#        '3.60 ', '1.65 ', '2.60 ', '2.90 ', '2.04 ', '45.0 Lac', '1.12 ',
# ...

# %%
Flat_prices["Price"] = Flat_prices["Price"].str.replace('Cr','')

# %%
Flat_prices.rename(columns={'Price':'Price_in_Cr'},inplace=Tue)

# %%
Flat_prices
# Out:
#     Price_in_Cr              BHK beds baths balcony Carpet Area  \
# 3         1.70                 3    3     2       4        1450
# 4     75.0 /100                3    3     3       1        1350
# 5         1.95                 3    3     3       4        1500
# 6         1.85                 3    3     3       3        1350
# 8         1.89                 3    3     3       2        1600
# ..          ...              ...  ...   ...     ...         ...
# 981   85.0 /100    725 Sq-ft  2     2     2       1         635
# 982   32.0 /100               2     2     1       1         350
# 983       2.50    1850 Sq-ft  3     3     3       1        1850
# 984   50.0 /100    150 Sq-ft  2     2     2       1         150
# 985       2.25                2     2     2       2        1250
#
#                         Floor Transaction type         Status  \
# 3        3 (Out of 10 Floors)           Resale  Ready to Move
# 4         3 (Out of 5 Floors)     New Property  Ready to Move
# ...

# %%
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('Lac','/100')

# %%
Flat_prices["Price_in_Cr"].unique()
# Out:
# array(['1.70 ', '75.0 /100', '1.95 ', '1.85 ', '1.89 ', '37.0 /100',
#        '4.05 ', '2.40 ', '2.45 ', '2.10 ', '27.5 /100', '61.5 /100',
#        '1.83 ', '1.15 ', '2.20 ', '1.62 ', '3.0 ', '1.20 ', '44.5 /100',
#        '2.47 ', '40.0 /100', '30.0 /100', '1.39 ', '93.0 /100', '1.28 ',
#        '3.15 ', '1.74 ', '4.85 ', '1.87 ', '24.5 /100', '1.73 ', '1.92 ',
#        '1.59 ', '22.5 /100', '1.11 ', '1.75 ', '2.0 ', '1.90 ', '2.30 ',
#        '21.0 /100', '4.50 ', '2.25 ', '1.32 ', '2.05 ', '55.0 /100',
#        '4.25 ', '1.17 ', '1.40 ', '1.60 ', '2.35 
#        '0.245', '1.73 ', '1.92 ', '1.59 ', '0.225', '1.11 ', '1.75 ',
#        '2.0 ', '1.90 ', '2.30 ', '0.21', '4.50 ', '2.25 ', '1.32 ',
#        '2.05 ', '0.55', '4.25 ', '1.17 ', '1.40 ', '1.60 ', '2.35 ',
#        '0.25', '1.64 ', '1.10 ', '4.10 ', '0.33', '2.70 ', '0.24',
#        '1.30 ', '7.50 ', '5.0 ', '5.50 ', '0.59', '21.50 ', '3.25 ',
#        '0.50', '0.65', '2.41 ', '4.60 ', '2.50 ', '5.99 ', '0.95',
#        '1.26 ', '1.67 ', '1.97 ', '3.30 ', '4.15 ', '3.80 ', '0.425',
#        '1.80 ', '1.05 ', '1.55 ', '6.50 ', '0.85', '3.60 ', '1.65 ',
#        '2.60 ', '2.90 ', '2.04 ', '0.45', '1.12 ', '0.295', '0.90',
#        '1.0 ', '1.50 ', '2.75 ', '0.70', '0.35', '0.42', '3.85 ', '0.47',
# ...

# %%
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('45.1 /100','0.451')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('53.5 /100','0.535')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('22.9 /100','0.229')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('71.0 /100','0.71')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('73.0 /100','0.73')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('63.0 /100','0.63')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('51.0 /100','0.51')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('54.5 /100','0.545')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('55.5 /100','0.555')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('39.0 /100','0.39')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('84.0 /100','0.84')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('98.0 /100','0.98')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('77.0 /100','0.77')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('53.0 /100','0.53')
Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('49.5 /100','0.495')
# Out:
# C:\Users\vishw\AppData\Local\Temp\ipykernel_22968\2930499999.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('45.1 /100','0.451')
# C:\Users\vishw\AppData\Local\Temp\ipykernel_22968\2930499999.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('53.5 /100','0.535')
# C:\Users\vishw\AppData\Local\Temp\ipykernel_22968\2930499999.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   Flat_prices["Price_in_Cr"] = Flat_prices["Price_in_Cr"].str.replace('22.9 /100','0.229')
# C:\Users\vishw\AppData\Local\Temp\ipykernel_22968\2930499999.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
Flat_prices["Price_in_Cr"] = Flat_prices.Price_in_Cr.astype(float)

# %%
Flat_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913 entries, 3 to 985
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price_in_Cr       913 non-null    float64
#  1   BHK               913 non-null    object
#  2   beds              913 non-null    object
#  3   baths             913 non-null    object
#  4   balcony           913 non-null    object
#  5   Carpet Area       913 non-null    object
#  6   Floor             913 non-null    object
#  7   Transaction type  913 non-null    object
#  8   Status            913 non-null    object
#  9   Address           913 non-null    object
#  10  Furnishing        913 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 85.6+ KB

# %%
Flat_prices["beds"] = Flat_prices.beds.astype(int)
Flat_prices["baths"] = Flat_prices.baths.astype(int)
Flat_prices["balcony"] = Flat_prices.balcony.astype(int)

# %%
Flat_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913 entries, 3 to 985
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price_in_Cr       913 non-null    float64
#  1   BHK               913 non-null    object
#  2   beds              913 non-null    int32
#  3   baths             913 non-null    int32
#  4   balcony           913 non-null    int32
#  5   Carpet Area       913 non-null    object
#  6   Floor             913 non-null    object
#  7   Transaction type  913 non-null    object
#  8   Status            913 non-null    object
#  9   Address           913 non-null    object
#  10  Furnishing        913 non-null    object
# dtypes: float64(1), int32(3), object(7)
# memory usage: 74.9+ KB

# %%
Flat_prices["Carpet Area"] = Flat_prices["Carpet Area"].str.replace('sqyrd','')
Flat_prices["Carpet Area"] = Flat_prices["Carpet Area"].str.replace('sqm','')
Flat_prices["Carpet Area"] = Flat_prices["Carpet Area"].str.replace(',','')

# %%
Flat_prices["Carpet Area"].unique()
# Out:
# array(['1450', '1350', '1500', '1600', '500', '1650', '1300', '1900',
#        '1750', '450', '1125', '1000', '1760', '1800', '720', '1850', '90',
#        '950', '1150', '1250', '1620', '265', '620', '1050', '520', '1100',
#        '1700', '75', '1200', '530', '1550', '120', '1400', '1950', '540',
#        '1570', '2000', '550', '650', '208', '3200', '193', '4200', '200',
#        '800', '900', '270', '1560', '2303', '810', '118', '1381', '1215',
#        '217', '1637', '850', '2100', '380', '700', '600', '2200', '2150',
#        '1440', '1680', '1590', '1720', '140', '495', '990', '225', '100',
#        '300', '250', '1325', '2160', '1365', '1090', '920', '3000',
#        '1480', '72', '890', '635', '1114', '85', '2300', '675', '55',
#        '80', '750', '510', '670', '825', '960', '1520', '891', '60',
#        '713', '1270', '1115', '320', '1836', '725', '1460', '1180', '858',
#        '603', '803', '68', '446', '924', '968', '754', '135', '624',
# ...

# %%
Flat_prices["Carpet Area"] = Flat_prices["Carpet Area"].astype(int)

# %%
Flat_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913 entries, 3 to 985
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price_in_Cr       913 non-null    float64
#  1   BHK               913 non-null    object
#  2   beds              913 non-null    int32
#  3   baths             913 non-null    int32
#  4   balcony           913 non-null    int32
#  5   Carpet Area       913 non-null    int32
#  6   Floor             913 non-null    object
#  7   Transaction type  913 non-null    object
#  8   Status            913 non-null    object
#  9   Address           913 non-null    object
#  10  Furnishing        913 non-null    object
# dtypes: float64(1), int32(4), object(6)
# memory usage: 71.3+ KB

# %%
Flat_prices
# Out:
#      Price_in_Cr              BHK  beds  baths  balcony  Carpet Area  \
# 3           1.70                3     3      2        4         1450
# 4           0.75                3     3      3        1         1350
# 5           1.95                3     3      3        4         1500
# 6           1.85                3     3      3        3         1350
# 8           1.89                3     3      3        2         1600
# ..           ...              ...   ...    ...      ...          ...
# 981         0.85    725 Sq-ft  2      2      2        1          635
# 982         0.32               2      2      1        1          350
# 983         2.50   1850 Sq-ft  3      3      3        1         1850
# 984         0.50    150 Sq-ft  2      2      2        1          150
# 985         2.25               2      2      2        2         1250
#
#                         Floor Transaction type         Status  \
# 3        3 (Out of 10 Floors)           Resale  Ready to Move
# ...

# %%
Flat_prices["BHK"].unique()
# Out:
# array(['3', '2', '3 ', '2 ', ' 1300 Sq-ft  2 ', ' 800 Sq-ft  2 ',
#        ' 1000 Sq-ft  3 ', ' 630 Sq-ft  2 ', ' 320 Sq-yrd  3 ',
#        ' 1800 Sq-ft  3 ', ' 500 Sq-ft  2 ', ' 550 Sq-ft  2 ',
#        ' 750 Sq-ft  2 ', ' 1600 Sq-ft  3 ', ' 1000 Sq-ft  2 ',
#        ' 900 Sq-ft  2 ', ' 1200 Sq-ft  3 ', ' 1550 Sq-ft  3 ',
#        ' 600 Sq-ft  2 ', ' 2000 Sq-ft  3 ', ' 1500 Sq-ft  3 ',
#        ' 1748 Sq-ft  3 ', ' 620 Sq-ft  2 ', ' 1400 Sq-ft  3 ',
#        ' 648 Sq-ft  2 ', ' 1200 Sq-ft  2 ', ' 855 Sq-ft  2 ',
#        ' 1150 Sq-ft  3 ', ' 2100 Sq-ft  3 ', ' 650 Sq-ft  2 ',
#        ' 90 Sq-yrd  3 ', ' 135 Sq-yrd  3 ', ' 950 Sq-ft  2 ',
#        ' 680 Sq-ft  3 ', ' 1300 Sq-ft  3 ', ' 91 Sq-m  2 ',
#        ' 1350 Sq-ft  3 ', ' 2200 Sq-ft  3 ', ' 1900 Sq-ft  3 ',
#        ' 1100 Sq-ft  3 ', ' 68 Sq-yrd  2 ', ' 445 Sq-ft  2 ',
#        ' 100 Sq-yrd  3 ', ' 1160 Sq-ft  2 ', ' 675 Sq-ft  3 ',
#        ' 1500 Sq-ft  2 ', ' 810 Sq-ft  3 ', ' 990 Sq-ft  2 ',
# ...

# %%
Flat_prices["BHK"] = Flat_prices["BHK"].str.replace('Sq-ft','')
Flat_prices["BHK"] = Flat_prices["BHK"].str.replace('Sq-yrd','')

# %%
Flat_prices["BHK"].unique()
# Out:
# array(['3', '2', '3 ', '2 ', ' 1300   2 ', ' 800   2 ', ' 1000   3 ',
#        ' 630   2 ', ' 320   3 ', ' 1800   3 ', ' 500   2 ', ' 550   2 ',
#        ' 750   2 ', ' 1600   3 ', ' 1000   2 ', ' 900   2 ', ' 1200   3 ',
#        ' 1550   3 ', ' 600   2 ', ' 2000   3 ', ' 1500   3 ',
#        ' 1748   3 ', ' 620   2 ', ' 1400   3 ', ' 648   2 ', ' 1200   2 ',
#        ' 855   2 ', ' 1150   3 ', ' 2100   3 ', ' 650   2 ', ' 90   3 ',
#        ' 135   3 ', ' 950   2 ', ' 680   3 ', ' 1300   3 ',
#        ' 91 Sq-m  2 ', ' 1350   3 ', ' 2200   3 ', ' 1900   3 ',
#        ' 1100   3 ', ' 68   2 ', ' 445   2 ', ' 100   3 ', ' 1160   2 ',
#        ' 675   3 ', ' 1500   2 ', ' 810   3 ', ' 990   2 ', ' 1728   3 ',
#        ' 1100   2 ', ' 725   2 ', ' 1850   3 ', ' 150   2 '], dtype=object)

# %%
Flat_prices
# Out:
#      Price_in_Cr         BHK  beds  baths  balcony  Carpet Area  \
# 3           1.70           3     3      2        4         1450
# 4           0.75           3     3      3        1         1350
# 5           1.95           3     3      3        4         1500
# 6           1.85           3     3      3        3         1350
# 8           1.89           3     3      3        2         1600
# ..           ...         ...   ...    ...      ...          ...
# 981         0.85    725   2      2      2        1          635
# 982         0.32          2      2      1        1          350
# 983         2.50   1850   3      3      3        1         1850
# 984         0.50    150   2      2      2        1          150
# 985         2.25          2      2      2        2         1250
#
#                         Floor Transaction type         Status  \
# 3        3 (Out of 10 Floors)           Resale  Ready to Move
# 4         3 (Out of 5 Floors)     New Property  Ready to Move
# ...
